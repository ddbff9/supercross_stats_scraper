# %%
from bs4 import BeautifulSoup
import requests
from p00_general_functions import *

# %%
'''
OBJECTIVE: Create a scraper that gets all results links from https://www.supercrosslive.com/ama-supercross-historical-results and
stores them as an object:

event_year: 2023
event_link: https://www.supercrosslive.com/event-results/01-anaheim-2022

'''
# Out:
# '\nOBJECTIVE: Create a scraper that gets all results links from https://www.supercrosslive.com/ama-supercross-historical-results and\nstores them as an object:\n\nevent_year: 2023\nevent_link: https://www.supercrosslive.com/event-results/01-anaheim-2022\n\n'

# %%
url = "https://www.supercrosslive.com/ama-supercross-historical-results"

# %%
page_html = scrapeHTML(url)

# %%
# Two tables hold all links to supercross results since 2013:
link_tables = page_html.find_all(class_="table-historical-class")

# %%
error_log = []
output = []

# Loop over each table and parse event info:
for table in link_tables:
  # Get list of link tags from table:
  table_rows = table.find_all("tr")
  for row in table_rows:
    cells = row.find_all("td")
    for cell in cells:
      results_link = ''
      link_text = ''
      round_num = ''
      round_location = ''
      year = ''
      year = cell.get('data-table-header')

      try:
        results_link = cell.find('a').get('href')
        link_text = cell.find('a').text.replace(u'\xa0', u' ').strip(' ')
        round_location = link_text.split('-')[1].replace(u'\xa0', u' ').strip(' ')
        round_num = link_text.split('-')[0].replace(u'\xa0', u' ').strip(' ')
        if (results_link == "/current-event-results"):
          pass
        else:
          if results_link == '/event-results/05-anaheim-iii':
            year = '2013'
          if results_link == '/event-results/12-toronto':
            year = '2014'
          if year == None:
            year = results_link[-4:]

          output.append([year,round_num,round_location, results_link])

      except:
        pass

# %%
output
# Out:
# [['2022', '01', 'Anaheim I', '/event-results/01-anaheim-2022'],
#  ['2021', '01', 'Houston I', '/event-results/00-houston-1-2021'],
#  ['2020', '01', 'Anaheim I', '/event-results/anaheim-i-2020'],
#  ['2019', '01', 'Anaheim I', '/event-results/anaheim-i-2019'],
#  ['2022', '02', 'Oakland', '/event-results/02-oakland-2022'],
#  ['2021', '02', 'Houston 2', '/event-results/02-houston-2-2021'],
#  ['2020', '02', 'St. Louis', '/event-results/st-louis-2020'],
#  ['2019', '02', 'Glendale', '/event-results/02-glendale-2019'],
#  ['2022', '03', 'San Diego', '/event-results/03-san-diego-2022'],
#  ['2021', '03', 'Houston 3', '/event-results/03-houston-3-2021'],
#  ['2020', '03', 'Anaheim II', '/event-results/anaheim-2-2020'],
#  ['2019', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2019'],
#  ['2022', '04', 'Anaheim II', '/event-results/04-anaheim-2022'],
#  ['2021', '04', 'Indianapolis 1', '/event-results/04-indianapolis-1-2021'],
#  ['2020', '04', 'Glendale', '/event-results/04-glendale-2020'],
#  ['2019', '04', 'Oakland', '/event-results/04-oakland-2019'],
#  ['2022', '05', 'Glendale', '/event-results/05-glendale-2022'],
#  ['2021', '05', 'Indianapolis 2', '/event-results/05-indianapolis-2021'],
#  ['2020', '05', 'Oakland', '/event-results/05-oakland-2020'],
#  ['2019', '05', 'San Diego', '/event-results/05-san-diego-2019'],
#  ['2022', '06', 'Anaheim III', '/event-results/06-anaheim-2022'],
#  ['2021', '06', 'Indianapolis 3', '/event-results/06-indianapolis-2021'],
#  ['2020', '06', 'San Diego', '/event-results/06-san-diego-2020'],
#  ['2019', '06', 'Minneapolis', '/event-results/06-minneapolis'],
#  ['2022', '07', 'Minneapolis', '/event-results/07-minneapolis-2022'],
#  ['2021', '07', 'Orlando 1', '/event-results/07-orlando-2021'],
#  ['2020', '07', 'Tampa', '/event-results/07-tampa-2020'],
#  ['2019', '07', 'Arlington', '/event-results/07-arlington'],
#  ['2022', '08', 'Arlington', '/event-results/08-arlington-2022'],
#  ['2021', '08', 'Orlando 2', '/event-results/08-orlando-2021'],
#  ['2020', '08', 'Arlington', '/event-results/08-arlington-2020'],
#  ['2019', '08', 'Detroit', '/event-results/08-detroit-2019'],
#  ['2022', '09', 'Daytona', '/event-results/09-daytona-2022'],
#  ['2021', '09', 'Daytona', '/event-results/09-daytona-2021'],
#  ['2020', '09', 'Atlanta', '/event-results/09-atlanta-2020'],
#  ['2019', '09', 'Atlanta', '/event-results/09-atlanta-2019'],
#  ['2022', '10', 'Detroit', '/event-results/10-detroit-2022'],
#  ['2021', '10', 'Arlington 1', '/event-results/10-arlington-2021'],
#  ['2020', '10', 'Daytona', '/event-results/10-daytona-beach-2020'],
#  ['2019', '10', 'Daytona', '/event-results/10-daytona-2019'],
#  ['2022', '11', 'Indy', '/event-results/11-indy-2022'],
#  ['2021', '11', 'Arlington 2', '/event-results/11-arlington-2021'],
#  ['2020', '11', 'Salt Lake City I', '/event-results/11-salt-lake-city-i-2020'],
#  ['2019', '11', 'Indianapolis', '/event-results/11-indianapolis-2019'],
#  ['2022', '12', 'Seattle', '/event-results/12-seattle-2022'],
#  ['2021', '12', 'Arlington 3', '/event-results/12-arlington-2021'],
#  ['2020', '12', 'Salt Lake City 2', '/event-results/12-salt-lake-city-2-2020'],
#  ['2019', '12', 'Seattle', '/event-results/12-seattle-2019'],
#  ['2022', '13', 'St. Louis', '/event-results/13-st-2022'],
#  ['2021', '13', 'Atlanta 1', '/event-results/13-atlanta-2021'],
#  ['2020', '13', 'Salt Lake City 3', '/event-results/13-salt-lake-city-3-2020'],
#  ['2019', '13', 'Houston', '/event-results/13-houston-2019'],
#  ['2022', '14', 'Atlanta', '/event-results/14-atlanta-2022'],
#  ['2021', '14', 'Atlanta 2', '/event-results/14-atlanta-2021'],
#  ['2020', '14', 'Salt Lake City 4', '/event-results/14-salt-lake-city-4-2020'],
#  ['2019', '14', 'Nashville', '/event-results/14-nashville-2019'],
#  ['2022', '15', 'Foxborough', '/event-results/15-foxborough-2022'],
#  ['2021', '15', 'Atlanta 3', '/event-results/15-atlanta-2021'],
#  ['2020', '15', 'Salt Lake City 5', '/event-results/15-salt-lake-city-5-2020'],
#  ['2019', '15', 'Denver', '/event-results/15-denver-2019'],
#  ['2022', '16', 'Denver', '/event-results/16-denver-2022'],
#  ['2021', '16', 'Salt Lake City 1', '/event-results/16-salt-2021'],
#  ['2020', '16', 'Salt Lake City 6', '/event-results/16-salt-lake-city-6-2020'],
#  ['2019', '16', 'East Rutherford', '/event-results/16-east-rutherford-2019'],
#  ['2022', '17', 'Salt Lake City', '/event-results/17-salt-lake-city-2022'],
#  ['2021', '17', 'Salt Lake City 2', '/event-results/17-salt-2021'],
#  ['2020', '17', 'Salt Lake City 7', '/event-results/17-salt-lake-city-7-2020'],
#  ['2019', '17', 'Las Vegas', '/event-results/17-las-vegas-2019'],
#  ['2019', '18', 'Monster Cup', '/event-results/18-monster-cup-2019'],
#  ['2018', '01', 'Anaheim I', '/event-results/01-anaheim-i-2018'],
#  ['2017', '01', 'Anaheim I', '/event-results/01-anaheim-i-2017'],
#  ['2016', '01', 'Anaheim I', '/event-results/01-anaheim-i-2016'],
#  ['2015', '01', 'Anaheim I', '/event-results/01-anaheim-i-2015'],
#  ['2014', '01', 'Anaheim I', '/event-results/01-anaheim-i-2014'],
#  ['2013', '01', 'Anaheim I', '/event-results/01-anaheim-i-2013'],
#  ['2018', '02', 'Houston', '/event-results/02-houston-2018'],
#  ['2017', '02', 'San Diego I', '/event-results/02-san-diego-i-2017'],
#  ['2016', '02', 'San Diego I', '/event-results/02-san-diego-i-2016'],
#  ['2015', '02', 'Phoenix', '/event-results/02-phoenix-2015'],
#  ['2014', '02', 'Phoenix', '/event-results/02-phoenix-2014'],
#  ['2013', '02', 'Phoenix', '/event-results/02-phoenix-2013'],
#  ['2018', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2018'],
#  ['2017', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2017'],
#  ['2016', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2016'],
#  ['2015', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2015'],
#  ['2014', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2014'],
#  ['2013', '03', 'Anaheim II', '/event-results/03-anaheim-ii-2013'],
#  ['2018', '04', 'Glendale', '/event-results/04-glendale'],
#  ['2017', '04', 'Phoenix', '/event-results/04-phoenix-2017'],
#  ['2016', '04', 'Oakland', '/event-results/04-oakland-2016'],
#  ['2015', '04', 'Oakland', '/event-results/04-oakland-2015'],
#  ['2014', '04', 'Oakland', '/event-results/04-oakland-2014'],
#  ['2013', '04', 'Oakland', '/event-results/04-oakland-2013'],
#  ['2018', '05', 'Oakland', '/event-results/05-oakland-2018'],
#  ['2017', '05', 'Oakland', '/event-results/05-oakland-2017'],
#  ['2016', '05', 'Glendale', '/event-results/05-glendale-2016'],
#  ['2015', '05', 'Anaheim III', '/event-results/05-anaheim-iii-2015'],
#  ['2014', '05', 'Anaheim III', '/event-results/05-anaheim-iii-2014'],
#  ['2013', '05', 'Anaheim III', '/event-results/05-anaheim-iii'],
#  ['2018', '06', 'San Diego', '/event-results/06-san-diego-2018'],
#  ['2017', '06', 'Arlington', '/event-results/06-arlington-2017'],
#  ['2016', '06', 'San Diego II', '/event-results/06-san-diego-ii-2016'],
#  ['2015', '06', 'San Diego', '/event-results/06-san-diego-2015'],
#  ['2014', '06', 'San Diego', '/event-results/06-san-diego-2014'],
#  ['2013', '06', 'San Diego', '/event-results/06-san-diego-2013'],
#  ['2018', '07', 'Arlington', '/event-results/07-arlington-2018'],
#  ['2017', '07', 'Minneapolis', '/event-results/07-minneapolis-2017'],
#  ['2016', '07', 'Arlington', '/event-results/07-arlington-2016'],
#  ['2015', '07', 'Arlington', '/event-results/07-arlington-2015'],
#  ['2014', '07', 'Arlington', '/event-results/07-arlington-2014'],
#  ['2013', '07', 'Arlington', '/event-results/07-arlington-2013'],
#  ['2018', '08', 'Tampa', '/event-results/08-tampa-2018'],
#  ['2017', '08', 'Atlanta I', '/event-results/08-atlanta-i-2017'],
#  ['2016', '08', 'Atlanta I', '/event-results/08-atlanta-i-2016'],
#  ['2015', '08', 'Atlanta I', '/event-results/08-atlanta-i-2015'],
#  ['2014', '08', 'Atlanta', '/event-results/08-atlanta-2014'],
#  ['2013', '08', 'Atlanta', '/event-results/08-atlanta-2013'],
#  ['2018', '09', 'Atlanta', '/event-results/09-atlanta-2018'],
#  ['2017', '09', 'Toronto', '/event-results/09-toronto-2017'],
#  ['2016', '09', 'Daytona', '/event-results/09-daytona-2016'],
#  ['2015', '09', 'Atlanta II', '/event-results/09-atlanta-ii-2015'],
#  ['2014', '09', 'Indianapolis', '/event-results/09-indianapolis-2014'],
#  ['2013', '09', 'St. Louis', '/event-results/09-st-louis-2013'],
#  ['2018', '10', 'Daytona', '/event-results/10-daytona-2018'],
#  ['2017', '10', 'Daytona', '/event-results/10-daytona-2017'],
#  ['2016', '10', 'Toronto', '/event-results/10-toronto-2016'],
#  ['2015', '10', 'Daytona', '/event-results/10-daytona-2015'],
#  ['2014', '10', 'Daytona', '/event-results/10-daytona-2014'],
#  ['2013', '10', 'Daytona', '/event-results/10-daytona-2013'],
#  ['2018', '11', 'St. Louis', '/event-results/11-st-louis-2018'],
#  ['2017', '11', 'Indianapolis', '/event-results/11-indianapolis-2017'],
#  ['2016', '11', 'Detroit', '/event-results/11-detroit-2016'],
#  ['2015', '11', 'Indianapolis', '/event-results/11-indianapolis-2015'],
#  ['2014', '11', 'Detroit', '/event-results/11-detroit-2014'],
#  ['2013', '11', 'Indianapolis', '/event-results/11-indianapolis-2013'],
#  ['2018', '12', 'Indianapolis', '/event-results/12-indianapolis-2018'],
#  ['2017', '12', 'Detroit', '/event-results/12-detroit-2017'],
#  ['2016', '12', 'Santa Clara', '/event-results/12-santa-clara-2016'],
#  ['2015', '12', 'Detroit', '/event-results/12-detroit-2015'],
#  ['2014', '12', 'Toronto', '/event-results/12-toronto'],
#  ['2013', '12', 'Toronto', '/event-results/12-toronto-2013'],
#  ['2018', '13', 'Seattle', '/event-results/13-seattle-2018'],
#  ['2017', '13', 'St Louis', '/event-results/13-st-louis-2017'],
#  ['2016', '13', 'Indianapolis', '/event-results/13-indianapolis-2016'],
#  ['2015', '13', 'St. Louis', '/event-results/13-st-louis-2015'],
#  ['2014', '13', 'St. Louis', '/event-results/13-st-louis-2014'],
#  ['2013', '13', 'Houston', '/event-results/13-houston-2013'],
#  ['2018', '14', 'Minneapolis', '/event-results/14-minneapolis-2018'],
#  ['2017', '14', 'Seattle', '/event-results/14-seattle-2017'],
#  ['2016', '14', 'St. Louis', '/event-results/14-st-louis-2016'],
#  ['2015', '14', 'Houston', '/event-results/14-houston-2015'],
#  ['2014', '14', 'Houston', '/event-results/14-houston-2014'],
#  ['2013', '14', 'Minneapolis', '/event-results/14-minneapolis-2013'],
#  ['2018', '15', 'Foxborough', '/event-results/15-foxborough-2018'],
#  ['2017', '15', 'Salt Lake City', '/event-results/15-salt-lake-city-2017'],
#  ['2016', '15', 'Foxborough', '/event-results/15-foxborough-2016'],
#  ['2015', '15', 'Santa Clara', '/event-results/15-santa-clara-2015'],
#  ['2014', '15', 'Seattle', '/event-results/15-seattle-2014'],
#  ['2013', '15', 'Seattle', '/event-results/15-seattle-2013'],
#  ['2018', '16', 'Salt Lake City', '/event-results/16-salt-lake-city-2018'],
#  ['2017', '16', 'New Jersey', '/event-results/16-new-jersey-2017'],
#  ['2016', '16', 'East Rutherford', '/event-results/16-east-rutherford-2016'],
#  ['2015', '16', 'East Rutherford', '/event-results/16-east-rutherford-2015'],
#  ['2014', '16', 'East Rutherford', '/event-results/16-east-rutherford-2014'],
#  ['2013', '16', 'Salt Lake City', '/event-results/16-salt-lake-city-2013'],
#  ['2018', '17', 'Las Vegas', '/event-results/17-las-vegas-2018'],
#  ['2017', '17', 'Las Vegas', '/event-results/17-las-vegas-2017'],
#  ['2016', '17', 'Las Vegas', '/event-results/17-las-vegas-2016'],
#  ['2015', '17', 'Las Vegas', '/event-results/17-las-vegas-2015'],
#  ['2014', '17', 'Las Vegas', '/event-results/17-las-vegas-2014'],
#  ['2013', '17', 'Las Vegas', '/event-results/17-las-vegas-2013'],
#  ['2018', '18', 'Monster Cup', '/event-results/18-monster-cup-2018'],
#  ['2017', '18', 'Monster Cup', '/event-results/18-monster-cup-2017'],
#  ['2016', '18', 'Monster Cup', '/event-results/18-monster-cup-2016'],
#  ['2015', '18', 'Monster Cup', '/event-results/18-monster-cup-2015'],
#  ['2014', '18', 'Monster Cup', '/event-results/18-monster-cup-2014'],
#  ['2013', '18', 'Monster Cup', '/event-results/18-monster-cup-2013']]
